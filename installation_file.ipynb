# %% [markdown]
# ### Install Required Library.

# %% [markdown]
# <!-- Firstly create the environment -->

# %%
# Firstly create the environment using the given commands.
# python -m venv .myenv


# actiavte the given env using the given command.
# .myenv\Scripts\activate

# %%
# Install libraries. 

# pip install LangGraph

# pip install LangChain

# pip install dotenv      --> working with environment variables.
